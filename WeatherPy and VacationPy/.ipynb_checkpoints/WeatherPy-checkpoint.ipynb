# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 616

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = 'https://api.openweathermap.org/data/2.5/weather'

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}?lat={lats[i]}&lon={lngs[i]}&appid={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        response = requests.get(city_url).json()
        # Parse the JSON and retrieve data
        city_weather = response['weather'][0]['main']
        

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = lats[i]
        city_lng = lngs[i]
        city_max_temp = response['main']['temp_max']
        city_humidity = response['main']['humidity']
        city_clouds = response['clouds']['all']
        city_wind = response['wind']['speed']
        city_country = citipy.nearest_city(lats[i], lngs[i]).country_code
        city_date = response['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | chokurdakh
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | port alfred
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | tumannyy
# Processing Record 6 of Set 1 | faanui
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | ravar
# Processing Record 9 of Set 1 | tabiauea
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | aquiraz
# Processing Record 12 of Set 1 | tiksi
# Processing Record 13 of Set 1 | seymchan
# Processing Record 14 of Set 1 | vaini
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | morehead
# Processing Record 18 of Set 1 | kinshasa
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | along
# Processing Record 21 of Set 1 | airai
# Processing Record 22 of Set 1 | westport
# Processing Record 23 of Set 1 | bethel
# Processing Record 24 of Set 1 | kahului
# Processing Record 25 of Set 1 | necochea
# Processing Record 26 of Set 1 | carnarvon
# Processing Record 27 of Set 1 | gambela
# Processing Record 28 of Set 1 | sentyabrskiy
# Processing Record 29 of Set 1 | castro
# Processing Record 30 of Set 1 | dikson
# Processing Record 31 of Set 1 | pevek
# Processing Record 32 of Set 1 | ixtapa
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | mar del plata
# Processing Record 35 of Set 1 | barrow
# Processing Record 36 of Set 1 | hilo
# Processing Record 37 of Set 1 | karachi
# Processing Record 38 of Set 1 | bima
# Processing Record 39 of Set 1 | gizo
# Processing Record 40 of Set 1 | russell
# Processing Record 41 of Set 1 | hobart
# Processing Record 42 of Set 1 | mahibadhoo
# Processing Record 43 of Set 1 | luderitz
# Processing Record 44 of Set 1 | namibe
# Processing Record 45 of Set 1 | kruisfontein
# Processing Record 46 of Set 1 | pangkalanbuun
# Processing Record 47 of Set 1 | tuktoyaktuk
# Processing Record 48 of Set 1 | urk
# Processing Record 49 of Set 1 | sao filipe
# Processing Record 50 of Set 1 | lata
# Processing Record 0 of Set 2 | ponta do sol
# Processing Record 1 of Set 2 | uglekamensk
# Processing Record 2 of Set 2 | meylan
# Processing Record 3 of Set 2 | georgetown
# Processing Record 4 of Set 2 | qaanaaq
# Processing Record 5 of Set 2 | ipixuna
# Processing Record 6 of Set 2 | illoqqortoormiut
# Processing Record 7 of Set 2 | baykit
# Processing Record 8 of Set 2 | pisco
# Processing Record 9 of Set 2 | mount gambier
# Processing Record 10 of Set 2 | haapiti
# Processing Record 11 of Set 2 | bredasdorp
# Processing Record 12 of Set 2 | santiago del estero
# Processing Record 13 of Set 2 | ushuaia
# Processing Record 14 of Set 2 | ayna
# Processing Record 15 of Set 2 | astoria
# Processing Record 41 of Set 3 | coquimbo
# Processing Record 42 of Set 3 | bad liebenwerda
# Processing Record 43 of Set 3 | karangasem
# Processing Record 44 of Set 3 | leh
# Processing Record 45 of Set 3 | nouadhibou
# Processing Record 46 of Set 3 | hamilton
# Processing Record 47 of Set 3 | havre-saint-pierre
# Processing Record 48 of Set 3 | grand gaube
# Processing Record 49 of Set 3 | vestmannaeyjar
# Processing Record 0 of Set 4 | vanersborg
# Processing Record 1 of Set 4 | klaksvik
# Processing Record 2 of Set 4 | camapua
# Processing Record 3 of Set 4 | kondagaon
# Processing Record 4 of Set 4 | lavrentiya
# Processing Record 5 of Set 4 | syamzha
# Processing Record 6 of Set 4 | mikuni
# Processing Record 7 of Set 4 | comodoro rivadavia
# Processing Record 8 of Set 4 | esperance
# Processing Record 9 of Set 4 | deskati
# Processing Record 10 of Set 4 | maceio
# Processing Record 11 of Set 4 | torbay
# Processing Record 12 of Set 4 | tonekabon
# Processing Record 13 of Set 4 | barentsburg
# Processing Record 14 of Set 4 | norden
# Processing Record 15 of Set 4 | katsina
# Processing Record 16 of Set 4 | lithgow
# Processing Record 17 of Set 4 | rodrigues alves
# Processing Record 18 of Set 4 | victoria
# Processing Record 19 of Set 4 | yelizovo
# Processing Record 20 of Set 4 | samusu
# Processing Record 21 of Set 4 | clyde river
# Processing Record 22 of Set 4 | ambilobe
# Processing Record 23 of Set 4 | amahai
# Processing Record 24 of Set 4 | talnakh
# Processing Record 25 of Set 4 | kismayo
# Processing Record 26 of Set 4 | passa quatro
# Processing Record 27 of Set 4 | vila franca do campo
# Processing Record 28 of Set 4 | maragogi
# Processing Record 29 of Set 4 | komsomolskiy
# Processing Record 30 of Set 4 | guerrero negro
# Processing Record 31 of Set 4 | amderma
# Processing Record 32 of Set 4 | jiangyou
# Processing Record 33 of Set 4 | tasiilaq
# Processing Record 34 of Set 4 | zernograd
# Processing Record 35 of Set 4 | olavarria
# Processing Record 36 of Set 4 | ribeira grande
# Processing Record 37 of Set 4 | vostok
# Processing Record 38 of Set 4 | ericeira
# Processing Record 39 of Set 4 | morondava
# Processing Record 40 of Set 4 | semnan
# Processing Record 41 of Set 4 | quatre cocos
# Processing Record 42 of Set 4 | touros
# Processing Record 43 of Set 4 | lagoa
# Processing Record 44 of Set 4 | alamosa
# Processing Record 45 of Set 4 | pali
# Processing Record 46 of Set 4 | wembley
# Processing Record 47 of Set 4 | tsihombe
# Processing Record 48 of Set 4 | tiznit
# Processing Record 49 of Set 4 | la ronge
# Processing Record 0 of Set 5 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 1 of Set 5 | khandyga
# Processing Record 2 of Set 5 | buta
# Processing Record 3 of Set 5 | marsa matruh
# Processing Record 4 of Set 5 | port shepstone
# Processing Record 5 of Set 5 | berlevag
# Processing Record 6 of Set 5 | saint george
# Processing Record 7 of Set 5 | nuuk
# Processing Record 8 of Set 5 | constitucion
# Processing Record 9 of Set 5 | tambo grande
# Processing Record 10 of Set 5 | saint-joseph
# Processing Record 11 of Set 5 | port lincoln
# Processing Record 12 of Set 5 | senanga
# Processing Record 13 of Set 5 | kavieng
# Processing Record 14 of Set 5 | ballina
# Processing Record 15 of Set 5 | ishinomaki
# Processing Record 16 of Set 5 | atar
# Processing Record 17 of Set 5 | hualmay
# Processing Record 18 of Set 5 | malartic
# Processing Record 19 of Set 5 | hyeres
# Processing Record 20 of Set 5 | fort nelson
# Processing Record 21 of Set 5 | laguna
# Processing Record 22 of Set 5 | padang
# Processing Record 23 of Set 5 | morant bay
# Processing Record 24 of Set 5 | vila velha
# Processing Record 25 of Set 5 | grande prairie
# Processing Record 26 of Set 5 | nyzhni sirohozy
# Processing Record 27 of Set 5 | jardim
# Processing Record 28 of Set 5 | aklavik
# Processing Record 29 of Set 5 | forbes
# Processing Record 30 of Set 5 | saint-georges
# Processing Record 31 of Set 5 | bolungarvik
# Processing Record 32 of Set 5 | sitka
# Processing Record 33 of Set 5 | arraial do cabo
# Processing Record 34 of Set 5 | broome
# Processing Record 35 of Set 5 | meadville
# Processing Record 36 of Set 5 | ribas do rio pardo
# Processing Record 37 of Set 5 | pangai
# Processing Record 38 of Set 5 | edgewood
# Processing Record 39 of Set 5 | ningan
# Processing Record 40 of Set 5 | gravdal
# Processing Record 41 of Set 5 | rawson
# Processing Record 42 of Set 5 | pacific grove
# Processing Record 43 of Set 5 | tubuala
# Processing Record 44 of Set 5 | attawapiskat
# Processing Record 45 of Set 5 | kenai
# Processing Record 46 of Set 5 | bathsheba
# Processing Record 47 of Set 5 | nome
# Processing Record 48 of Set 5 | longyearbyen
# Processing Record 49 of Set 5 | sao joao da barra
# Processing Record 0 of Set 6 | dingle
# Processing Record 1 of Set 6 | nizhneyansk
# Processing Record 2 of Set 6 | vallenar
# Processing Record 3 of Set 6 | mabaruma
# Processing Record 4 of Set 6 | saint-leu
# Processing Record 5 of Set 6 | mys shmidta
# Processing Record 6 of Set 6 | severo-kurilsk
# Processing Record 7 of Set 6 | mombetsu
# Processing Record 8 of Set 6 | kununurra
# Processing Record 9 of Set 6 | robertsport
# Processing Record 10 of Set 6 | port keats
# Processing Record 11 of Set 6 | nishihara
# Processing Record 12 of Set 6 | kieta
# Processing Record 13 of Set 6 | nizhniy ingash
# Processing Record 14 of Set 6 | bud
# Processing Record 15 of Set 6 | mugla
# Processing Record 16 of Set 6 | nipawin
# Processing Record 17 of Set 6 | saskylakh
# Processing Record 18 of Set 6 | talara
# Processing Record 19 of Set 6 | pictou
# Processing Record 20 of Set 6 | praxedis guerrero
# Processing Record 21 of Set 6 | warrnambool
# Processing Record 22 of Set 6 | vaitupu
# Processing Record 23 of Set 6 | joshimath
# Processing Record 24 of Set 6 | aparan
# Processing Record 25 of Set 6 | saint-philippe
# Processing Record 26 of Set 6 | coahuayana
# Processing Record 27 of Set 6 | yulara
# Processing Record 28 of Set 6 | zhigansk
# Processing Record 29 of Set 6 | barabai
# Processing Record 30 of Set 6 | salalah
# Processing Record 31 of Set 6 | meitingen
# Processing Record 32 of Set 6 | alofi
# Processing Record 33 of Set 6 | washington
# Processing Record 34 of Set 6 | pyapon
# Processing Record 35 of Set 6 | dunyapur
# Processing Record 36 of Set 6 | lebu
# Processing Record 37 of Set 6 | hollins
# Processing Record 38 of Set 6 | shiyan
# Processing Record 39 of Set 6 | svetlogorsk
# Processing Record 40 of Set 6 | richards bay
# Processing Record 41 of Set 6 | contai
# Processing Record 42 of Set 6 | liverpool
# Processing Record 43 of Set 6 | anadyr
# Processing Record 44 of Set 6 | ilulissat
# Processing Record 45 of Set 6 | saint-francois
# Processing Record 46 of Set 6 | alice springs
# Processing Record 47 of Set 6 | brawley
# Processing Record 48 of Set 6 | calabozo
# Processing Record 49 of Set 6 | halmstad
# Processing Record 0 of Set 7 | cairns
# Processing Record 1 of Set 7 | azoyu
# Processing Record 2 of Set 7 | awjilah
# Processing Record 3 of Set 7 | canala
# Processing Record 4 of Set 7 | shirokiy
# Processing Record 5 of Set 7 | atlantic beach
# Processing Record 6 of Set 7 | port augusta
# Processing Record 7 of Set 7 | berezna
# Processing Record 8 of Set 7 | griffith
# Processing Record 9 of Set 7 | taksimo
# Processing Record 10 of Set 7 | mitsamiouli
# Processing Record 11 of Set 7 | leningradskiy
# Processing Record 12 of Set 7 | leshukonskoye
# Processing Record 13 of Set 7 | broken hill
# Processing Record 14 of Set 7 | portland
# Processing Record 15 of Set 7 | avera
# Processing Record 16 of Set 7 | raga
# Processing Record 17 of Set 7 | graaff-reinet
# Processing Record 18 of Set 7 | udachnyy
# Processing Record 19 of Set 7 | san patricio
# Processing Record 20 of Set 7 | noumea
# Processing Record 21 of Set 7 | dabakala
# Processing Record 22 of Set 7 | sisimiut
# Processing Record 23 of Set 7 | avanigadda
# Processing Record 24 of Set 7 | atalanti
# Processing Record 25 of Set 7 | flin flon
# Processing Record 26 of Set 7 | fuling
# Processing Record 27 of Set 7 | siilinjarvi
# Processing Record 28 of Set 7 | shimoda
# Processing Record 29 of Set 7 | mangai
# Processing Record 30 of Set 7 | faya
# Processing Record 31 of Set 7 | miyako
# Processing Record 32 of Set 7 | inverness
# Processing Record 33 of Set 7 | palabuhanratu
# Processing Record 34 of Set 7 | waihi beach
# Processing Record 35 of Set 7 | madang
# Processing Record 36 of Set 7 | skelleftea
# Processing Record 37 of Set 7 | kattivakkam
# Processing Record 38 of Set 7 | nara
# Processing Record 39 of Set 7 | hay river
# Processing Record 40 of Set 7 | boda
# Processing Record 41 of Set 7 | virtsu
# Processing Record 42 of Set 7 | puerto leguizamo
# Processing Record 43 of Set 7 | vilhena
# Processing Record 44 of Set 7 | bogande
# Processing Record 45 of Set 7 | vagur
# Processing Record 46 of Set 7 | campoverde
# Processing Record 47 of Set 7 | shimorskoye
# Processing Record 48 of Set 7 | wajid
# Processing Record 49 of Set 7 | kayerkan
# Processing Record 0 of Set 8 | solnechnyy
# Processing Record 1 of Set 8 | hunza
# Processing Record 2 of Set 8 | port blair
# Processing Record 3 of Set 8 | punto fijo
# Processing Record 4 of Set 8 | balkanabat
# Processing Record 5 of Set 8 | wellington
# Processing Record 6 of Set 8 | hasaki
# Processing Record 7 of Set 8 | balsta
# Processing Record 8 of Set 8 | nata
# Processing Record 9 of Set 8 | mezen
# Processing Record 10 of Set 8 | dhidhdhoo
# Processing Record 11 of Set 8 | cabo san lucas
# Processing Record 12 of Set 8 | harper
# Processing Record 13 of Set 8 | northam
# Processing Record 14 of Set 8 | malwan
# Processing Record 15 of Set 8 | yar-sale
# Processing Record 16 of Set 8 | los llanos de aridane
# Processing Record 43 of Set 9 | andrushivka
# Processing Record 44 of Set 9 | lafia
# Processing Record 45 of Set 9 | mehran
# Processing Record 46 of Set 9 | chernyshevskiy
# Processing Record 47 of Set 9 | srednekolymsk
# Processing Record 48 of Set 9 | siavonga
# Processing Record 49 of Set 9 | vila
# Processing Record 0 of Set 10 | ust-bolsheretsk
# Processing Record 1 of Set 10 | valleyview
# Processing Record 2 of Set 10 | newport
# Processing Record 3 of Set 10 | babanusah
# Processing Record 4 of Set 10 | bedesa
# Processing Record 5 of Set 10 | santa isabel do rio negro
# Processing Record 6 of Set 10 | moranbah
# Processing Record 7 of Set 10 | sibiti
# Processing Record 8 of Set 10 | marcona
# Processing Record 9 of Set 10 | yumen
# Processing Record 10 of Set 10 | hamadan
# Processing Record 11 of Set 10 | rozivka
# Processing Record 12 of Set 10 | chikhli
# Processing Record 13 of Set 10 | sabaudia
# Processing Record 14 of Set 10 | brindisi
# Processing Record 15 of Set 10 | ratanpur
# Processing Record 16 of Set 10 | poshekhonye
# Processing Record 17 of Set 10 | gondanglegi
# Processing Record 18 of Set 10 | macaboboni
# Processing Record 19 of Set 10 | sweetwater
# Processing Record 20 of Set 10 | yellandu
# Processing Record 21 of Set 10 | ajra
# Processing Record 22 of Set 10 | znamenskoye
# Processing Record 23 of Set 10 | hokitika
# Processing Record 24 of Set 10 | saleaula
# Processing Record 25 of Set 10 | namatanai
# Processing Record 26 of Set 10 | nyurba
# Processing Record 27 of Set 10 | trairi
# Processing Record 28 of Set 10 | urdzhar
# Processing Record 29 of Set 10 | winburg
# Processing Record 30 of Set 10 | taburi
# Processing Record 31 of Set 10 | valavanur
# Processing Record 32 of Set 10 | adrar
# Processing Record 33 of Set 10 | isiro
# Processing Record 34 of Set 10 | sobolevo
# Processing Record 35 of Set 10 | dwarka
# Processing Record 36 of Set 10 | xapuri
# Processing Record 37 of Set 10 | santo antonio do taua
# Processing Record 38 of Set 10 | cao bang
# Processing Record 39 of Set 10 | caravelas
# Processing Record 40 of Set 10 | portsmouth
# Processing Record 41 of Set 10 | aksu
# Processing Record 42 of Set 10 | moron
# Processing Record 43 of Set 10 | nago
# Processing Record 44 of Set 10 | lashio
# Processing Record 45 of Set 10 | burica
# Processing Record 46 of Set 10 | crestview
# Processing Record 47 of Set 10 | flinders
# Processing Record 48 of Set 10 | ozernovskiy
# Processing Record 49 of Set 10 | tabou
# Processing Record 0 of Set 11 | evora
# Processing Record 1 of Set 11 | utiroa
# Processing Record 2 of Set 11 | kulhudhuffushi
# Processing Record 3 of Set 11 | lumding
# Processing Record 4 of Set 11 | eskasem
# Processing Record 5 of Set 11 | zhezkazgan
# Processing Record 6 of Set 11 | kodinsk
# Processing Record 7 of Set 11 | te anau
# Processing Record 8 of Set 11 | sinnamary
# Processing Record 9 of Set 11 | yokadouma
# Processing Record 10 of Set 11 | ciudad bolivar
# Processing Record 11 of Set 11 | saint-louis
# Processing Record 12 of Set 11 | pangnirtung
# Processing Record 13 of Set 11 | shaowu
# Processing Record 14 of Set 11 | zhuhai
# Processing Record 15 of Set 11 | noboribetsu
# Processing Record 16 of Set 11 | karratha
# Processing Record 17 of Set 11 | valparaiso
# Processing Record 18 of Set 11 | helong
# Processing Record 19 of Set 11 | port moresby
# Processing Record 20 of Set 11 | haines junction
# Processing Record 21 of Set 11 | sembabule
# Processing Record 22 of Set 11 | kupang
# Processing Record 23 of Set 11 | najran
# Processing Record 24 of Set 11 | kodiak
# Processing Record 25 of Set 11 | tiarei
# Processing Record 26 of Set 11 | scottsbluff
# Processing Record 27 of Set 11 | tarakan
# Processing Record 28 of Set 11 | iwaki
# Processing Record 29 of Set 11 | skotterud
# Processing Record 30 of Set 11 | san vicente
# Processing Record 31 of Set 11 | sorland
# Processing Record 32 of Set 11 | kloulklubed
# Processing Record 33 of Set 11 | qaqortoq
# Processing Record 34 of Set 11 | worthing
# Processing Record 35 of Set 11 | trincomalee
# Processing Record 36 of Set 11 | naral
# Processing Record 37 of Set 11 | araguaina
# Processing Record 38 of Set 11 | arlit
# Processing Record 39 of Set 11 | raudeberg
# Processing Record 40 of Set 11 | mandan
# Processing Record 41 of Set 11 | mongu
# Processing Record 42 of Set 11 | portree
# Processing Record 43 of Set 11 | middelburg
# Processing Record 44 of Set 11 | mehamn
# Processing Record 45 of Set 11 | rypefjord
# Processing Record 46 of Set 11 | bindura
# Processing Record 47 of Set 11 | ampanihy
# Processing Record 48 of Set 11 | we
# Processing Record 49 of Set 11 | marystown
# Processing Record 0 of Set 12 | terme
# Processing Record 1 of Set 12 | menongue
# Processing Record 2 of Set 12 | bowen
# Processing Record 3 of Set 12 | olafsvik
# Processing Record 4 of Set 12 | axim
# Processing Record 5 of Set 12 | genoa
# Processing Record 6 of Set 12 | mamallapuram
# Processing Record 7 of Set 12 | meadow lake
# Processing Record 8 of Set 12 | nanuque
# Processing Record 9 of Set 12 | oistins
# Processing Record 10 of Set 12 | alugan
# Processing Record 11 of Set 12 | manyana
# Processing Record 12 of Set 12 | mattawa
# Processing Record 13 of Set 12 | saint-tite
# Processing Record 14 of Set 12 | njombe
# Processing Record 15 of Set 12 | brenham
# Processing Record 16 of Set 12 | paka
# Processing Record 17 of Set 12 | kota belud
# Processing Record 18 of Set 12 | bontang
# Processing Record 19 of Set 12 | olinda
# Processing Record 20 of Set 12 | baruun-urt
# Processing Record 21 of Set 12 | aykhal
# Processing Record 22 of Set 12 | quesnel
# Processing Record 23 of Set 12 | whitehorse
# Processing Record 24 of Set 12 | borogontsy
# Processing Record 25 of Set 12 | waipawa
# Processing Record 26 of Set 12 | novyy urengoy
# Processing Record 27 of Set 12 | anshun
# Processing Record 28 of Set 12 | half moon bay
# Processing Record 29 of Set 12 | taltal
# Processing Record 30 of Set 12 | edd
# Processing Record 31 of Set 12 | darhan
# Processing Record 32 of Set 12 | tyumentsevo
# Processing Record 33 of Set 12 | rolim de moura
# Processing Record 34 of Set 12 | mandali
# Processing Record 35 of Set 12 | huadian
# Processing Record 36 of Set 12 | san nicolas
# Processing Record 37 of Set 12 | teya
# Processing Record 38 of Set 12 | poum
# Processing Record 39 of Set 12 | nanzhou
# Processing Record 40 of Set 12 | darab
# Processing Record 41 of Set 12 | la palma
# Processing Record 42 of Set 12 | baripada
# Processing Record 43 of Set 12 | tulum
# Processing Record 44 of Set 12 | san cristobal
# Processing Record 45 of Set 12 | adolfo lopez mateos
# Processing Record 46 of Set 12 | catamarca
# Processing Record 47 of Set 12 | japura
# Processing Record 48 of Set 12 | katherine
# Processing Record 49 of Set 12 | shah alam
# Processing Record 0 of Set 13 | omemee
# Processing Record 1 of Set 13 | hirara
# Processing Record 2 of Set 13 | deggendorf
# Processing Record 3 of Set 13 | krasnoselkup
# Processing Record 4 of Set 13 | gashua
# Processing Record 5 of Set 13 | suraabad
# Processing Record 6 of Set 13 | camiri
# Processing Record 7 of Set 13 | tungor
# Processing Record 8 of Set 13 | umzimvubu
# Processing Record 9 of Set 13 | korla
# Processing Record 10 of Set 13 | monrovia
# Processing Record 11 of Set 13 | edgewater
# Processing Record 12 of Set 13 | christchurch
# Processing Record 13 of Set 13 | meulaboh
# Processing Record 14 of Set 13 | bandrele
# Processing Record 15 of Set 13 | lodwar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          615
# Lat           615
# Lng           615
# Max Temp      615
# Humidity      615
# Cloudiness    615
# Wind Speed    615
# Country       615
# Date          615
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City        Lat         Lng  Max Temp  Humidity  Cloudiness
# 0    chokurdakh  78.002472  146.193437    273.45        90          36  \
# 1         bluff -77.093638  171.698325    235.44       100          97
# 2   port alfred -43.985768   29.357910    283.24        82          91
# 3  punta arenas -78.429197  -88.086156    231.72        96          75
# 4      tumannyy  73.286565   37.833604    281.26        93         100
#
#    Wind Speed Country        Date
# 0        5.14      ru  1691465838
# 1        4.21      nz  1691465838
# 2       16.53      za  1691465839
# 3        3.94      cl  1691465839
# 4        7.80      ru  1691465840

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City        Lat         Lng  Max Temp  Humidity  Cloudiness
# City_ID
# 0          chokurdakh  78.002472  146.193437    273.45        90          36  \
# 1               bluff -77.093638  171.698325    235.44       100          97
# 2         port alfred -43.985768   29.357910    283.24        82          91
# 3        punta arenas -78.429197  -88.086156    231.72        96          75
# 4            tumannyy  73.286565   37.833604    281.26        93         100
#
#          Wind Speed Country        Date
# City_ID
# 0              5.14      ru  1691465838
# 1              4.21      nz  1691465838
# 2             16.53      za  1691465839
# 3              3.94      cl  1691465839
# 4              7.80      ru  1691465840

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
latitude = city_data_df["Lat"]
temperature = city_data_df["Max Temp"]
plt.scatter(latitude, temperature, edgecolor="black", marker="o")

# Incorporate the other graph properties
plt.title(f"City Max Latitude vs Temperature "+ time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
latitude = city_data_df["Lat"]
humidity = city_data_df["Humidity"]
plt.scatter(latitude, humidity, edgecolor="black", marker="o")

# Incorporate the other graph properties
plt.title(f"City Latitude vs Humidity "+ time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
latitude = city_data_df["Lat"]
cloudiness = city_data_df["Cloudiness"]
plt.scatter(latitude, cloudiness, edgecolor="black", marker="o")

# Incorporate the other graph properties
plt.title(f"City Latitude vs Cloudiness "+ time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
latitude = city_data_df["Lat"]
wind_speed = city_data_df["Wind Speed"]
plt.scatter(latitude, wind_speed, edgecolor="black", marker="o")

# Incorporate the other graph properties
plt.title(f"City Latitude vs Wind Speed "+ time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
x_values = city_data_df.Lat
y_values = city_data_df['Max Temp']

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                City        Lat         Lng  Max Temp  Humidity  Cloudiness
# City_ID
# 0        chokurdakh  78.002472  146.193437    273.45        90          36  \
# 4          tumannyy  73.286565   37.833604    281.26        93         100
# 7             ravar  31.727472   58.027984    307.36        14           0
# 13            vaini  83.294382  128.296236    273.54        99          99
# 14           albany  62.094665  152.947456    273.83        95         100
#
#          Wind Speed Country        Date
# City_ID
# 0              5.14      ru  1691465838
# 4              7.80      ru  1691465840
# 7              5.33      ir  1691465842
# 13             4.81      ru  1691465844
# 14             2.95      ru  1691465845

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City        Lat         Lng  Max Temp  Humidity  Cloudiness
# City_ID
# 1               bluff -77.093638  171.698325    235.44       100          97  \
# 2         port alfred -43.985768   29.357910    283.24        82          91
# 3        punta arenas -78.429197  -88.086156    231.72        96          75
# 5              faanui  -3.778324 -157.659044    300.82        72          37
# 6             rikitea -30.733960 -121.430347    290.10        62          86
#
#          Wind Speed Country        Date
# City_ID
# 1              4.21      nz  1691465838
# 2             16.53      za  1691465839
# 3              3.94      cl  1691465839
# 5              7.57      pf  1691465840
# 6              5.08      pf  1691465842

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# %%
# Build the scatter plots for Northern Hemisphere Linear regression
latitude = northern_hemi_df["Lat"]
temperature = northern_hemi_df["Max Temp"]
plt.scatter(latitude, temperature, edgecolor="black", marker="o")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.plot(x_values, regress_values, "r-")

# Show r value
print(f"The r value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r value is: 0.7304846774976087

# %%
# Linear Regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# %%
# Build the scatter plots for Southern Hemisphere Linear regression
latitude = southern_hemi_df["Lat"]
temperature = southern_hemi_df["Max Temp"]
plt.scatter(latitude, temperature, edgecolor="black", marker="o")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.plot(x_values, regress_values, "r-")

# Show r value
print(f"The r value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r value is: 0.3151456322671751

# %% [markdown]
# **Discussion about the linear relationship:** The linear relationship between latitude and maximum temperature varies within the Northern and Southern hemispheres. In the Northern hemisphere, the linear relationship is negative. This means that when latitude increases, maximum temperature decreases. However, in the Southern hemisphere, the linear relationship is positive. This means that when latitude increases, maximum temperature also increases. (I realize that my linear regression line is incorrect for the Southern Hemisphere, so my answer is based on the trend that I am seeing in the data, and not my linear regression line).

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Linear Regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# %%
# Build the scatter plots for Northern Hemisphere Linear regression
latitude = northern_hemi_df["Lat"]
humidity = northern_hemi_df["Humidity"]
plt.scatter(latitude, humidity, edgecolor="black", marker="o")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.plot(x_values, regress_values, "r-")

# Show r value
print(f"The r value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r value is: 0.030652310635464947

# %%
# Linear Regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# %%
# Build the scatter plots for Southern Hemisphere Linear regression
latitude = southern_hemi_df["Lat"]
humidity = southern_hemi_df["Humidity"]
plt.scatter(latitude, humidity, edgecolor="black", marker="o")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.plot(x_values, regress_values, "r-")

# Show r value
print(f"The r value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r value is: 0.3151456322671751

# %% [markdown]
# **Discussion about the linear relationship:** The linear relationship between latitude and humidity is pretty weak for both hemispheres. In the Northern Hemisphere, the relationship is slightly positive, indicating that as latitude increases, humidity also increases. In the Southern Hemisphere, the relationship is slightly negative, indicating that as latitude increases, humidity decreases.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Linear Regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# %%
# Build the scatter plots for Northern Hemisphere Linear regression
latitude = northern_hemi_df["Lat"]
cloudiness = northern_hemi_df["Cloudiness"]
plt.scatter(latitude, cloudiness, edgecolor="black", marker="o")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.plot(x_values, regress_values, "r-")

# Show r value
print(f"The r value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r value is: 0.03241642061685157

# %%
# Linear Regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# %%
# Build the scatter plots for Southern Hemisphere Linear regression
latitude = southern_hemi_df["Lat"]
cloudiness = southern_hemi_df["Cloudiness"]
plt.scatter(latitude, cloudiness, edgecolor="black", marker="o")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.plot(x_values, regress_values, "r-")

# Show r value
print(f"The r value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r value is: 0.12396002224928002

# %% [markdown]
# **Discussion about the linear relationship:** The linear relationship between latitude and cloudiness is pretty weak for both hemispheres. In the Northern Hemisphere, the relationship is slightly positive, indicating that as latitude increases, cloudiness also increases. In the Southern Hemisphere, the relationship is slightly negative, indicating that as latitude increases, cloudiness decreases.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Linear Regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# %%
# Build the scatter plots for Northern Hemisphere Linear regression
latitude = northern_hemi_df["Lat"]
wind_speed = northern_hemi_df["Wind Speed"]
plt.scatter(latitude, wind_speed, edgecolor="black", marker="o")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.plot(x_values, regress_values, "r-")

# Show r value
print(f"The r value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r value is: 0.018405639843172554

# %%
# Linear Regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# %%
# Build the scatter plots for Southern Hemisphere Linear regression
latitude = southern_hemi_df["Lat"]
wind_speed = southern_hemi_df["Wind Speed"]
plt.scatter(latitude, wind_speed, edgecolor="black", marker="o")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.plot(x_values, regress_values, "r-")

# Show r value
print(f"The r value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r value is: 0.011764111003655126

# %% [markdown]
# **Discussion about the linear relationship:** In both the Northern and Southern Hemispheres, the relationship between latitude and wind speed is slightly negative. This means that when latitude increases, wind speed decreases.
